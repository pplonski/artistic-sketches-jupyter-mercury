# %% [raw]
# ---
# title: Convert Photo to Sketch 🖌️
# description: Create sketch from uploaded a photo
# show-code: False
# params:
#     image_path:
#         input: file
#         label: Please upload a photo
#     output_dir:
#         output: dir
# ---

# %% [markdown]
# # 🎨 Convert photo to sketch 🎨

# %%
import os
import cv2
from PIL import Image
from matplotlib import pyplot as plt

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12,12)
mpl.rcParams['axes.grid'] = False

# %%
image_path = "/home/piotr/Downloads/153185874-f24cd6fe-9c64-4fa5-8b41-3814856d330a.png"
output_dir = "output_images"

# %%
def imshow(image, title=None, fname=None):
    if len(image.shape) > 3:
        image = tf.squeeze(image, axis=0)

    plt.imshow(image)
    plt.axis('off')
    if title:
        plt.title(title)
    if fname:
        plt.savefig(fname)

# %%
image = Image.open(image_path)

# %%
img = cv2.imread(image_path)
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## 📷 Your image

# %%
imshow(RGB_img)

# %%
grayed = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
inverted = cv2.bitwise_not(grayed)

# %%
blurred = cv2.GaussianBlur(inverted, (19, 19), sigmaX=0, sigmaY=0)

# %%
def blend(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_result = blend(grayed, blurred)

# %%
_ = cv2.imwrite(os.path.join(output_dir, "sketch_photo.jpg"), final_result)

# %%
RGB_img = cv2.cvtColor(final_result, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ## 💻 Your sketch

# %%
imshow(RGB_img)

# %% [markdown]
# ### The output image is saved in the Output Files. You can download it from there 😊
